# %%
# Loading data from Google Sheets
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/1ecopK6oyyb4d_7-QLrCr8YlgFrCetHU7-VQfnYej7JY/export?format=xlsx"
dataset = pd.ExcelFile(url, engine='openpyxl')

sheets = []
for sheet in dataset.sheet_names:
    df = dataset.parse(sheet)
    df["sheet"] = sheet #adding a column to track from which sheet is the data
    sheets.append(df)

df_airbnb = pd.concat(sheets, ignore_index=True)

# %%
# Check the shape of the combined DataFrame
df_airbnb.shape
# Out:
# (51707, 21)

# %%
# Exploratory Data Analysis (EDA)
# Create a column for country and weekday/weekend from group column
df_airbnb['city'] = df_airbnb['sheet'].str.split('_').str[0]
df_airbnb['weekday/weekend'] = df_airbnb['sheet'].str.split('_').str[1]

# %%
df_airbnb['city'].unique()
# Out:
# array(['amsterdam', 'athens', 'berlin', 'barcelona', 'budapest', 'lisbon',
#        'london', 'paris', 'rome', 'vienna'], dtype=object)

# %%
# Create a column for country by mapping city names
country_map = {'amsterdam': 'netherlands', 
               'athens': 'greece',
               'berlin': 'germany',
               'barcelona': 'spain',
               'budapest': 'hungary',
               'lisbon': 'portugal',
               'london': 'uk',
               'paris': 'france',
               'rome': 'italy',
               'vienna': 'austria'}

df_airbnb['country'] = df_airbnb['city'].replace(country_map)

# %%
# Change the name of realSum to price
df_airbnb.rename(columns={'realSum': 'price'}, inplace=True)

# %%
# Instead of having two columns of room_shared and room_private, create one with the respective categories (was combined with room type)
df_airbnb['room_type'] = df_airbnb.apply(
    lambda row: 'shared room' if row['room_shared'] == True 
        else ('private room' if row['room_private'] == True 
              else 'entire home/apt'), axis=1)

df_airbnb = df_airbnb.drop(columns=['room_shared', 'room_private'])

# %%
# create a column where one can know if the host of the listing has only one, two to four, or more than four listings based on column multi and biz
df_airbnb['host_listing_count'] = df_airbnb.apply(
    lambda row: 'more than four' if row['biz'] == 1
    else ('one' if row['multi'] == 0
          else 'two to four'), axis=1)

df_airbnb = df_airbnb.drop(columns=['biz', 'multi'])

# %%
df_airbnb.shape
# Out:
# (51707, 21)

# %%
# Display the first entry
df_airbnb.head(1)
# Out:
#    Unnamed: 0       price     room_type  person_capacity  host_is_superhost  \
# 0           0  194.033698  private room                2              False
#
#    cleanliness_rating  guest_satisfaction_overall  bedrooms      dist  \
# 0                  10                          93         1  5.022964
#
#    metro_dist  ...  attr_index_norm  rest_index  rest_index_norm      lng  \
# 0     2.53938  ...         4.166708   98.253896         6.846473  4.90569
#
#         lat               sheet       city weekday/weekend      country  \
# 0  52.41772  amsterdam_weekdays  amsterdam        weekdays  netherlands
#
#   host_listing_count
# 0        two to four
#
# [1 rows x 21 columns]

# %%
# Display the last entry
df_airbnb.tail(1)
# Out:
#        Unnamed: 0       price     room_type  person_capacity  \
# 51706        1798  133.230489  private room                4
#
#        host_is_superhost  cleanliness_rating  guest_satisfaction_overall  \
# 51706               True                  10                          93
#
#        bedrooms      dist  metro_dist  ...  attr_index_norm  rest_index  \
# 51706         1  1.263932    0.480903  ...        10.774264  225.247293
#
#        rest_index_norm       lng       lat            sheet    city  \
# 51706          5.44414  16.39066  48.20811  vienna_weekends  vienna
#
#       weekday/weekend  country host_listing_count
# 51706        weekends  austria        two to four
#
# [1 rows x 21 columns]

# %%
# Display random sample of 7 entries
df_airbnb.sample(7)
# Out:
#        Unnamed: 0       price        room_type  person_capacity  \
# 2429          349   86.940220  entire home/apt                4
# 2434          354   90.455323  entire home/apt                3
# 21007        1451  216.228893  entire home/apt                5
# 12449        1050  120.324901     private room                2
# 8848          288  347.761055  entire home/apt                2
# 24155        1693  109.833251     private room                2
# 13301         624  133.242468  entire home/apt                4
#
#        host_is_superhost  cleanliness_rating  guest_satisfaction_overall  \
# 2429               False                   9                          95
# 2434                True                  10                          98
# 21007              False                   9                          92
# 12449               True                   9                          90
# 8848               False                   9                          87
# 24155              False                  10                         100
# 13301               True                   9                          95
#
#        bedrooms      dist  metro_dist  ...  attr_index_norm  rest_index  \
# 2429          1  3.694986    0.389358  ...         1.715476   62.911018
# 2434          1  2.780092    0.596741  ...         2.541818  101.986078
# 21007         2  2.439231    0.672802  ...         3.572866  266.557596
# 12449         2  4.828414    0.102734  ...         7.594670  289.412380
# 8848          0  8.754093    0.910233  ...        10.003326  115.390668
# 24155         1  7.516524    0.557976  ...        11.431346  344.166752
# 13301         1  1.304250    0.191635  ...        14.724962  399.266272
#
#        rest_index_norm       lng       lat               sheet       city  \
# 2429          4.723742  23.77107  37.99317     athens_weekdays     athens
# 2434          7.657735  23.71418  37.99414     athens_weekdays     athens
# 21007        14.981242  -9.12700  38.73200     lisbon_weekends     lisbon
# 12449         6.357418   2.14047  41.42451  barcelona_weekends  barcelona
# 8848         23.792766  13.29593  52.49559     berlin_weekdays     berlin
# 24155         6.162593  -0.02619  51.53215     london_weekdays     london
# 13301        30.233670  19.06409  47.50820   budapest_weekdays   budapest
#
#       weekday/weekend   country host_listing_count
# 2429         weekdays    greece        two to four
# 2434         weekdays    greece        two to four
# 21007        weekends  portugal     more than four
# 12449        weekends     spain        two to four
# 8848         weekdays   germany                one
# 24155        weekdays        uk                one
# 13301        weekdays   hungary                one
#
# [7 rows x 21 columns]

# %%
# Check data types
df_airbnb.dtypes
# Out:
# Unnamed: 0                      int64
# price                         float64
# room_type                      object
# person_capacity                 int64
# host_is_superhost                bool
# cleanliness_rating              int64
# guest_satisfaction_overall      int64
# bedrooms                        int64
# dist                          float64
# metro_dist                    float64
# attr_index                    float64
# attr_index_norm               float64
# rest_index                    float64
# rest_index_norm               float64
# lng                           float64
# lat                           float64
# sheet                          object
# city                           object
# weekday/weekend                object
# country                        object
# host_listing_count             object
# dtype: object

# %%
# basic summary statistics for numeric data
df_airbnb.describe()
# Out:
#          Unnamed: 0         price  person_capacity  cleanliness_rating  \
# count  51707.000000  51707.000000     51707.000000        51707.000000
# mean    1620.502388    279.879591         3.161661            9.390624
# std     1217.380366    327.948386         1.298545            0.954868
# min        0.000000     34.779339         2.000000            2.000000
# 25%      646.000000    148.752174         2.000000            9.000000
# 50%     1334.000000    211.343089         3.000000           10.000000
# 75%     2382.000000    319.694287         4.000000           10.000000
# max     5378.000000  18545.450285         6.000000           10.000000
#
#        guest_satisfaction_overall     bedrooms          dist    metro_dist  \
# count                51707.000000  51707.00000  51707.000000  51707.000000
# mean                    92.628232      1.15876      3.191285      0.681540
# std                      8.945531      0.62741      2.393803      0.858023
# min                     20.000000      0.00000      0.015045      0.002301
# 25%                     90.000000      1.00000      1.453142      0.248480
# 50%                     95.000000      1.00000      2.613538      0.413269
# 75%                     99.000000      1.00000      4.263077      0.737840
# max                    100.000000     10.00000     25.284557     14.273577
#
#          attr_index  attr_index_norm    rest_index  rest_index_norm  \
# count  51707.000000     51707.000000  51707.000000     51707.000000
# mean     294.204105        13.423792    626.856696        22.786177
# std      224.754123         9.807985    497.920226        17.804096
# min       15.152201         0.926301     19.576924         0.592757
# 25%      136.797385         6.380926    250.854114         8.751480
# 50%      234.331748        11.468305    522.052783        17.542238
# 75%      385.756381        17.415082    832.628988        32.964603
# max     4513.563486       100.000000   6696.156772       100.000000
#
#                 lng           lat
# count  51707.000000  51707.000000
# mean       7.426068     45.671128
# std        9.799725      5.249263
# min       -9.226340     37.953000
# 25%       -0.072500     41.399510
# 50%        4.873000     47.506690
# 75%       13.518825     51.471885
# max       23.786020     52.641410

# %%
# basic summary statistics for categorical data
df_airbnb.describe(include="object")
